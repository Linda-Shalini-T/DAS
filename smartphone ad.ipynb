# %%
import pandas as pd

# Load the uploaded CSV file to inspect its contents
file_path = 'Mobile phone price.csv'
mobile_data = pd.read_csv(file_path)

# Display the first few rows and basic information about the dataset
mobile_data.head(), mobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 25.6+ KB
# (     Brand              Model Storage    RAM  Screen Size (inches)  \
#  0    Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
#  1  Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
#  2  OnePlus              9 Pro   128 GB   8 GB                  6.7
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert numerical columns (if necessary)
mobile_data['Price ($)'] = pd.to_numeric(mobile_data['Price ($)'], errors='coerce')
mobile_data['Screen Size (inches)'] = pd.to_numeric(mobile_data['Screen Size (inches)'], errors='coerce')

# Data preparation: Analyze the relationship between price and other numerical factors
correlation_data = mobile_data[['Price ($)', 'Battery Capacity (mAh)', 'Screen Size (inches)']].corr()

# Generate a heatmap for correlation analysis
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_data, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Price and Features')
plt.show()
price_bins = pd.cut(data['Price ($)'], bins=[0, 300, 600, 1000, 1500, 2000], labels=['<300', '300-600', '600-1000', '1000-1500', '>1500'])
brand_price_dist = data.groupby(['Brand', price_bins]).size().unstack().fillna(0).loc[top_brands.index]

brand_price_dist.plot(
    kind='bar', 
    stacked=True, 
    figsize=(12, 8), 
    color=plt.cm.Set3.colors, 
    edgecolor='black'
)
plt.title('Price Ranges Across Top Brands', fontsize=16, color="darkblue")
plt.xlabel('Brand', fontsize=12, color="darkgreen")
plt.ylabel('Number of Models', fontsize=12, color="darkgreen")
plt.xticks(rotation=45, fontsize=10)
plt.legend(title='Price Range ($)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

stacked_bar_path = '/mnt/data/price_ranges_stacked_bar.png'
plt.savefig(stacked_bar_path)
plt.show()

# %%
# Create the Pie Chart: Market Distribution by Brand with vibrant colors
plt.figure(figsize=(8, 8))
brand_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.tab20.colors[:len(brand_counts)],
    wedgeprops={'edgecolor': 'black'},
)
plt.title('Market Distribution by Top 5 Brands', fontsize=16, color='darkblue')
plt.ylabel('')  # Remove y-label for cleaner appearance
plt.tight_layout()

# Save the pie chart with vibrant colors
pie_chart_colorful_path = 'market_distribution_pie_chart.png'

plt.show()

# %%
price_bins = pd.cut(data['Price ($)'], bins=[0, 300, 600, 1000, 1500, 2000], labels=['<300', '300-600', '600-1000', '1000-1500', '>1500'])
brand_price_dist = data.groupby(['Brand', price_bins]).size().unstack().fillna(0).loc[top_brands.index]

brand_price_dist.plot(
    kind='bar', 
    stacked=True, 
    figsize=(12, 8), 
    color=plt.cm.Set3.colors, 
    edgecolor='black'
)
plt.title('Price Ranges Across Top Brands', fontsize=16, color="darkblue")
plt.xlabel('Brand', fontsize=12, color="darkgreen")
plt.ylabel('Number of Models', fontsize=12, color="darkgreen")
plt.xticks(rotation=45, fontsize=10)
plt.legend(title='Price Range ($)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

stacked_bar_path = '/mnt/data/price_ranges_stacked_bar.png'

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12628\3288898374.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   brand_price_dist = data.groupby(['Brand', price_bins]).size().unstack().fillna(0).loc[top_brands.index]
